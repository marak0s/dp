# %% [markdown]
# # 00 Quickstart
# Быстрый запуск маленького эксперимента AWGN.

# %%
from pathlib import Path
import sys
def find_repo_root(start: Path) -> Path:
    cur = start.resolve()
    while cur != cur.parent:
        if (cur / 'pyproject.toml').exists():
            return cur
        cur = cur.parent
    raise RuntimeError('Repo root not found')
ROOT = find_repo_root(Path.cwd())
if str(ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(ROOT / 'src'))
print('ROOT=', ROOT)

# %%
from comm_ai.experiments.run_experiment import run
out = run(str(ROOT/'src/comm_ai/config/experiments/awgn_small.yaml'))
out

# %%
import pandas as pd
from IPython.display import display
df = pd.read_csv(out/'results.csv')
display(df.head())
print('Artifacts:', list(p.name for p in out.iterdir()))

# %%
from IPython.display import Image, display
display(Image(filename=str(out/'ber_plot.png')))
display(Image(filename=str(out/'timing_plot.png')))
